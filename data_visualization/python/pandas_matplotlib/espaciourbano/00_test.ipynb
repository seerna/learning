# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
x = [1, 2, 3]
y = [1, 4, 9]
z = [10, 5, 0]
plt.plot(x, y)
plt.plot(x, z)
plt.title("test plot")
plt.xlabel("x")
plt.ylabel("y and z")
plt.legend(['this is y','this is z'])
plt.show()

# %%
sample_data = pd.read_csv('output.csv')

# %%
sample_data["Precio"] = sample_data["Precio"].str.replace(",","").astype(int)

# %%
sample_data
# Out:
#        Código Tipo propiedad Tipo contrato   Precio  \
# 0     1346030    Apartamento   EN ARRIENDO  1600000
# 1     1346019    Apartamento   EN ARRIENDO  1300000
# 2     1346012    Apartamento   EN ARRIENDO  1900000
# 3     1345986    Apartamento   EN ARRIENDO   850000
# 4     1345960    Apartamento   EN ARRIENDO  1350000
# ...       ...            ...           ...      ...
# 5860  1267997    Apartamento   EN ARRIENDO  1050000
# 5861  1262474    Apartamento   EN ARRIENDO  1100000
# 5862  1259972    Apartamento   EN ARRIENDO  1100000
# 5863  1256237    Apartamento   EN ARRIENDO  1250000
# 5864  1254087    Apartamento   EN ARRIENDO  1100000
#
#                                             Descripción                Ciudad  \
# 0     apartamento aproximadamente de 58 m2 ubicado e...                 Bello
# 1     apartamento aproximadamente de 55 m2 ubicado e...                 Bello
# 2     Apartamento aproximadamente de 63 m2 ubicado e...                 Bello
# ...

# %%
type(sample_data)
# Out:
# pandas.core.frame.DataFrame

# %%
sample_data.Ciudad
# Out:
# 0                      Bello
# 1                      Bello
# 2                      Bello
# 3                      Bello
# 4                      Bello
#                 ...
# 5860    San Antonio de Prado
# 5861    San Antonio de Prado
# 5862    San Antonio de Prado
# 5863    San Antonio de Prado
# 5864    San Antonio de Prado
# Name: Ciudad, Length: 5865, dtype: object

# %%
sample_data.Ciudad.iloc[5218]
# Out:
# 'Sabaneta'

# %%
cheap = sample_data[sample_data.Precio < 1000000]

# %%
cheap
# Out:
#        Código Tipo propiedad Tipo contrato  Precio  \
# 3     1345986    Apartamento   EN ARRIENDO  850000
# 6     1345805    Apartamento   EN ARRIENDO  650000
# 7     1345733    Apartamento   EN ARRIENDO  900000
# 17    1345527    Apartamento   EN ARRIENDO  850000
# 38    1344855    Apartamento   EN ARRIENDO  750000
# ...       ...            ...           ...     ...
# 5849  1291162    Apartamento   EN ARRIENDO  950000
# 5852  1287919    Apartamento   EN ARRIENDO  980000
# 5853  1287624    Apartamento   EN ARRIENDO  950000
# 5857  1275394    Apartamento   EN ARRIENDO  900000
# 5859  1273418    Apartamento   EN ARRIENDO  950000
#
#                                             Descripción                Ciudad  \
# 3     APARTAMENTO EN ARRIENDO TIERRADENTRO La propie...                 Bello
# 6     3 º pisoSala comedor, 2 alcobas, 1 closet, 1 b...                 Bello
# 7     11 º pisoSala comedor, 2 alcobas, 2 closets, 1...                 Bello
# ...

# %%
sabaneta = sample_data[(sample_data.Ciudad == 'Sabaneta') & (sample_data['Tipo propiedad'] == 'Apartamento')]

# %%
sabaneta
# Out:
#        Código Tipo propiedad Tipo contrato   Precio  \
# 5180  1346014    Apartamento   EN ARRIENDO  3600000
# 5181  1345978    Apartamento   EN ARRIENDO  2000000
# 5182  1345971    Apartamento   EN ARRIENDO  1750000
# 5183  1345931    Apartamento   EN ARRIENDO  2800000
# 5184  1345831    Apartamento   EN ARRIENDO  2900000
# ...       ...            ...           ...      ...
# 5773  1056100    Apartamento   EN ARRIENDO  3000000
# 5774  1055613    Apartamento   EN ARRIENDO  2700000
# 5775   972855    Apartamento   EN ARRIENDO  3000000
# 5776   845724    Apartamento   EN ARRIENDO  3200000
# 5777   815532    Apartamento   EN ARRIENDO  3000000
#
#                                             Descripción    Ciudad  \
# 5180  80m2, 3 alcobas, 2 baños, 2 closets mas vestie...  Sabaneta
# 5181  Apartamento con acabados modernos, espacios ge...  Sabaneta
# 5182  Aprox 68 metros, sala comedor, 3 alcobas, 3 cl...  Sabaneta
# 5183  El lugar soñado para ti y tu familia ubicada e...  Sabaneta
# ...

# %%
unique = sample_data['Barrio / Sector'].unique()

# %%
unique
# Out:
# array(['Barrio Obrero', 'Santa Ana', 'Tierradentro', 'Niquía', 'Cabañas',
#        'El Trapiche', 'Navarra', 'Cabañitas', 'La Gabriela', 'Bellavista',
#        'Amazonia', 'La Madera', 'Barrio Central', 'Machado', 'Mirador',
#        'Molinares', 'Paraiso', 'San Gabriel', 'Barrio Nuevo', 'Bucaros',
#        'Puerto Bello', 'Araucarias II', 'Vegas', 'Serramonte',
#        'Buenos Aires', 'Trapiche', 'Villas del Sol', 'Fontidueño',
#        'Carmelo', 'Congolo', 'París', 'Maruchenga', 'Gran Avenida',
#        'Porvenir', 'Prado', 'Niquía Terranova', 'Alcalá', 'La Cumbre',
#        'Tricentenario', 'Barrio Perez', 'Niquía Puerta del Norte',
#        'Calle Vieja', 'Parque', 'Norte America', 'Centro', 'Florida',
#        'Manchester', 'Belalcazar', 'Rosario', 'Andalucía',
#        'Niquía Camacol', 'Belvedere', 'Las Brisas', 'La Camila',
#        'Villa de Confenalco', 'Baladares', 'LA TABLAZA', 'Primavera',
#        'Caldas', 'olaya herrera', 'la miel', 'caldas', 'Holaya Herrera',
# ...
